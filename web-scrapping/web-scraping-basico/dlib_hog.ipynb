# %%
# !pip install dlib==19.22.99
# !pip install opencv-python-headless imutils
# Out:
# ERROR: Could not find a version that satisfies the requirement dlib==19.22.99 (from versions: 18.17.100, 19.0.0, 19.1.0, 19.3.1, 19.4.0, 19.5.0, 19.5.1, 19.6.0, 19.6.1, 19.7.0, 19.8.0, 19.8.1, 19.8.2, 19.9.0, 19.10.0, 19.12.0, 19.13.0, 19.13.1, 19.14.0, 19.15.0, 19.16.0, 19.17.0, 19.18.0, 19.19.0, 19.20.0, 19.21.0, 19.21.1, 19.22.0, 19.22.1, 19.23.0, 19.23.1, 19.24.0, 19.24.1, 19.24.2, 19.24.4, 19.24.5, 19.24.6, 19.24.8, 19.24.9, 20.0.0)
# ERROR: No matching distribution found for dlib==19.22.99
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: imutils in /usr/local/lib/python3.12/dist-packages (0.5.4)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python-headless) (2.0.2)

# %% [markdown]
# ## Video desde archivo

# %%
import cv2, dlib, time

detector = dlib.get_frontal_face_detector()
cap = cv2.VideoCapture('video_rostros.mp4')  # sube tu video corto

prev = time.time(); frames=0
while True:
    ok, frame = cap.read()
    if not ok: break
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    rects = detector(gray, 0)  # 0 = sin upsampling
    for r in rects:
        x,y,w,h = r.left(), r.top(), r.width(), r.height()
        cv2.rectangle(frame, (x,y), (x+w,y+h), (0,255,0), 2)
    frames += 1
    if frames % 10 == 0:
        now = time.time(); fps = 10/(now-prev); prev=now
        cv2.putText(frame, f"FPS: {fps:.1f}", (10,30),
                    cv2.FONT_HERSHEY_SIMPLEX, 1,(0,255,0),2)
    # Mostrar frame en notebook (en local usa imshow)
    _, buf = cv2.imencode('.jpg', frame)
    # en Colab podrías guardar frames si quieres
cap.release()
